# %%
# !meltano init speedrun
# Out:
# /bin/bash: meltano: command not found

# %%
# !pip list
# Out:
# Package                        Version    Editable project location
# ------------------------------ ---------- ----------------------------------------------------------
# absl-py                        0.11.0
# aiohttp                        3.8.1
# aiosignal                      1.2.0
# alembic                        1.4.1
# ansiwrap                       0.8.4
# anyio                          3.4.0
# argcomplete                    1.12.3
# argon2-cffi                    21.1.0
# astroid                        2.6.6
# astunparse                     1.6.3
# async-timeout                  4.0.1
# asynctest                      0.13.0
# attrs                          21.2.0
# autopage                       0.4.0
# autopep8                       1.5.5
# awscli                         1.22.21
# Babel                          2.9.1
# backcall                       0.2.0
# black                          21.12b0
# bleach                         4.1.0
# ...
